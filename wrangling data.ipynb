# %%
import matplotlib.pyplot as plt 
import pandas as dp 
import numpy as np
import seaborn as sns

df = dp.read_csv('tmdb-movies.csv')
# df.describe(include='all')
# df.info()

# %%
# no_years = (df.release_year.max() - df.release_year.min())

# %%
df.drop(columns={'id', 'imdb_id', 'homepage', 'overview', 'release_date', 'keywords', 'tagline','production_companies', 'budget_adj', 'revenue_adj'}, inplace=True)
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df.drop(index=df[df['revenue']==0].index, inplace=True)

# %%
df.dtypes
# Out:
# popularity        float64
# budget              int64
# revenue             int64
# original_title     object
# cast               object
# director           object
# runtime             int64
# genres             object
# vote_count          int64
# vote_average      float64
# release_year        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['popularity', 'budget', 'revenue', 'original_title', 'cast', 'director',
#        'runtime', 'genres', 'vote_count', 'vote_average', 'release_year'],
#       dtype='object')

# %%
# df['original_title'].nunique() #10439
# df['original_title'].value_counts()

# %%
# df['cast'].nunique() #10665
# df['cast'].value_counts()

# %%
# df['director'].nunique() #5018
# df['director'].value_counts()

# %%
# df['genres'].nunique() #2022
# df['genres'].value_counts()

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'budget'}>,
#         <Axes: title={'center': 'revenue'}>],
#        [<Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'vote_count'}>,
#         <Axes: title={'center': 'vote_average'}>],
#        [<Axes: title={'center': 'release_year'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# max profit
df['profit'] = df['revenue'] - df['budget']
max_profit = df['profit'].max()
df[df['profit'] == max_profit]
# Out:
#       popularity     budget     revenue original_title  \
# 1386    9.432768  237000000  2781505847         Avatar
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#       runtime                                    genres  vote_count  \
# 1386      162  Action|Adventure|Fantasy|Science Fiction        8458
#
#       vote_average  release_year      profit
# 1386           7.1          2009  2544505847

# %%
# top cost
max_budget = df['budget'].max()
df[df['budget'] == max_budget]
# Out:
#       popularity     budget   revenue     original_title  \
# 2244     0.25054  425000000  11087569  The Warrior's Way
#
#                                                    cast    director  runtime  \
# 2244  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee      100
#
#                                          genres  vote_count  vote_average  \
# 2244  Adventure|Fantasy|Action|Western|Thriller          74           6.4
#
#       release_year     profit
# 2244          2010 -413912431

# %%
#top revenue
max_rev = df['revenue'].max()
df[df['revenue'] == max_rev]
# Out:
#       popularity     budget     revenue original_title  \
# 1386    9.432768  237000000  2781505847         Avatar
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#       runtime                                    genres  vote_count  \
# 1386      162  Action|Adventure|Fantasy|Science Fiction        8458
#
#       vote_average  release_year      profit
# 1386           7.1          2009  2544505847
